# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from openpyxl import load_workbook
wb = load_workbook('book2.xlsx')

from openpyxl import Workbook
ws = wb.active
sheet = ws
sheet.delete_cols(idx=21, amount=1)
sheet.delete_cols(idx=17, amount=3)
sheet.delete_cols(idx=13, amount=2)
sheet.delete_cols(idx=5, amount=6)
sheet.delete_cols(idx=3, amount=1)
sheet.delete_cols(idx=1, amount=1)

wb.save("./book3.xlsx")

# %%
df1 = pd.read_excel('book3.xlsx')

# %%
cond1 = (df1['목장'] == '향샘1')
cond2 = (df1['목장'] == '향샘2')
cond3 = (df1['목장'] == '향샘3')
cond4 = (df1['목장'] == '향샘4')
cond5 = (df1['목장'] == '날샘1')
cond6 = (df1['목장'] == '날샘2')
cond7 = (df1['목장'] == '날샘3')
cond8 = (df1['목장'] == '날샘4')
cond9 = (df1['목장'] == '아샘1')
cond10 = (df1['목장'] == '아샘2')
cond11 = (df1['목장'] == '아샘3')
cond12 = (df1['목장'] == '아샘4')
cond13 = (df1['목장'] == '은샘1')
cond14 = (df1['목장'] == '은샘2')
cond15 = (df1['목장'] == '은샘3')
cond16 = (df1['목장'] == '은샘4')
cond17 = (df1['목장'] == '정샘1')
cond18 = (df1['목장'] == '정샘2')
cond19 = (df1['목장'] == '정샘3')
cond20 = (df1['목장'] == '정샘4')
cond21 = (df1['목장'] == '풍샘1')
cond22 = (df1['목장'] == '풍샘2')
cond23 = (df1['목장'] == '풍샘3')
cond24 = (df1['목장'] == '풍샘4')
cond25 = (df1['목장'] == '풍샘5')
cond26 = (df1['목장'] == '풍샘6')
cond27 = (df1['목장'] == '풍샘7')
cond28 = (df1['목장'] == '풍샘8')
cond29 = (df1['목장'] == '시샘1')
cond30 = (df1['목장'] == '시샘2')
cond31 = (df1['목장'] == '시샘3')
cond32 = (df1['목장'] == '시샘4')
cond33 = (df1['목장'] == '시샘5')
cond34 = (df1['목장'] == '시샘6')
cond35 = (df1['목장'] == '실버1')

# %%
df3 = df1.loc[cond1] 
df3.to_excel('향샘1.xlsx', encoding='cp949')
df4 = df1.loc[cond2]
df4.to_excel('향샘2.xlsx', encoding='cp949')
df5 = df1.loc[cond3]
df5.to_excel('향샘3.xlsx', encoding='cp949')
df6 = df1.loc[cond4]
df6.to_excel('향샘4.xlsx', encoding='cp949')
df7 = df1.loc[cond5]
df7.to_excel('날샘1.xlsx', encoding='cp949')
df8 = df1.loc[cond6]
df8.to_excel('날샘2.xlsx', encoding='cp949')
df9 = df1.loc[cond7]
df9.to_excel('날샘3.xlsx', encoding='cp949')
df10 = df1.loc[cond8]
df10.to_excel('날샘4.xlsx', encoding='cp949')
df11 = df1.loc[cond9]
df11.to_excel('아샘1.xlsx', encoding='cp949')
df12 = df1.loc[cond10]
df12.to_excel('아샘2.xlsx', encoding='cp949')
df13 = df1.loc[cond11]
df13.to_excel('아샘3.xlsx', encoding='cp949')
df14 = df1.loc[cond12]
df14.to_excel('아샘4.xlsx', encoding='cp949')
df15 = df1.loc[cond13]
df15.to_excel('은샘1.xlsx', encoding='cp949')
df16 = df1.loc[cond14]
df16.to_excel('은샘2.xlsx', encoding='cp949')
df17 = df1.loc[cond15]
df17.to_excel('은샘3.xlsx', encoding='cp949')
df18 = df1.loc[cond16]
df18.to_excel('은샘4.xlsx', encoding='cp949')
df19 = df1.loc[cond17]
df19.to_excel('정샘1.xlsx', encoding='cp949')
df20 = df1.loc[cond18]
df20.to_excel('정샘2.xlsx', encoding='cp949')
df21 = df1.loc[cond19]
df21.to_excel('정샘3.xlsx', encoding='cp949')
df22 = df1.loc[cond20]
df22.to_excel('정샘4.xlsx', encoding='cp949')
df23 = df1.loc[cond21]
df23.to_excel('풍샘1.xlsx', encoding='cp949')
df24 = df1.loc[cond22]
df24.to_excel('풍샘2.xlsx', encoding='cp949')
df25 = df1.loc[cond23]
df25.to_excel('풍샘3.xlsx', encoding='cp949')
df26 = df1.loc[cond24]
df26.to_excel('풍샘4.xlsx', encoding='cp949')
df27 = df1.loc[cond25]
df27.to_excel('풍샘5.xlsx', encoding='cp949')
df28 = df1.loc[cond26]
df28.to_excel('풍샘6.xlsx', encoding='cp949')
df29 = df1.loc[cond27]
df29.to_excel('풍샘7.xlsx', encoding='cp949')
df30 = df1.loc[cond28]
df30.to_excel('풍샘8.xlsx', encoding='cp949')
df31 = df1.loc[cond29]
df31.to_excel('시샘1.xlsx', encoding='cp949')
df32 = df1.loc[cond30]
df32.to_excel('시샘2.xlsx', encoding='cp949')
df33 = df1.loc[cond31]
df33.to_excel('시샘3.xlsx', encoding='cp949')
df34 = df1.loc[cond32]
df34.to_excel('시샘4.xlsx', encoding='cp949')
df35 = df1.loc[cond33]
df35.to_excel('시샘5.xlsx', encoding='cp949')
df36 = df1.loc[cond34]
df36.to_excel('시샘6.xlsx', encoding='cp949')
df37 = df1.loc[cond35]
df37.to_excel('실버1.xlsx', encoding='cp949')

# %%
for i in range(1,5):
    name = '향샘{}.xlsx'.format(i) 
    from openpyxl import load_workbook
    from openpyxl import Workbook
    wb = load_workbook(name)
    ws = wb.active
    sheet = ws
    sheet.column_dimensions["G"].width = 15
    sheet.column_dimensions["F"].width = 15
    wb.save(name)

# %%
for i in range(1,5):
    name = '날샘{}.xlsx'.format(i) 
    from openpyxl import load_workbook
    from openpyxl import Workbook
    wb = load_workbook(name)
    ws = wb.active
    sheet = ws
    sheet.column_dimensions["G"].width = 15
    sheet.column_dimensions["F"].width = 15
    wb.save(name)

# %%
for i in range(1,5):
    name = '아샘{}.xlsx'.format(i) 
    from openpyxl import load_workbook
    from openpyxl import Workbook
    wb = load_workbook(name)
    ws = wb.active
    sheet = ws
    sheet.column_dimensions["G"].width = 15
    sheet.column_dimensions["F"].width = 15
    wb.save(name)

# %%
for i in range(1,5):
    name = '은샘{}.xlsx'.format(i) 
    from openpyxl import load_workbook
    from openpyxl import Workbook
    wb = load_workbook(name)
    ws = wb.active
    sheet = ws
    sheet.column_dimensions["G"].width = 15
    sheet.column_dimensions["F"].width = 15
    wb.save(name)

# %%
for i in range(1,5):
    name = '정샘{}.xlsx'.format(i) 
    from openpyxl import load_workbook
    from openpyxl import Workbook
    wb = load_workbook(name)
    ws = wb.active
    sheet = ws
    sheet.column_dimensions["G"].width = 15
    sheet.column_dimensions["F"].width = 15
    wb.save(name)

# %%
for i in range(1,9):
    name = '풍샘{}.xlsx'.format(i) 
    from openpyxl import load_workbook
    from openpyxl import Workbook
    wb = load_workbook(name)
    ws = wb.active
    sheet = ws
    sheet.column_dimensions["G"].width = 15
    sheet.column_dimensions["F"].width = 15
    wb.save(name)

# %%
for i in range(1,7):
    name = '시샘{}.xlsx'.format(i) 
    from openpyxl import load_workbook
    from openpyxl import Workbook
    wb = load_workbook(name)
    ws = wb.active
    sheet = ws
    sheet.column_dimensions["G"].width = 15
    sheet.column_dimensions["F"].width = 15
    wb.save(name)

# %%
for i in range(1,2):
    name = '실버{}.xlsx'.format(i) 
    from openpyxl import load_workbook
    from openpyxl import Workbook
    wb = load_workbook(name)
    ws = wb.active
    sheet = ws
    sheet.column_dimensions["G"].width = 15
    sheet.column_dimensions["F"].width = 15
    wb.save(name)
